# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/content/drive/MyDrive/DATA_Computer_Vision/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread('abcd')

# %%
type(img)
# Out:
# NoneType

# %%
img = cv2.imread('/content/drive/MyDrive/DATA_Computer_Vision/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[78, 81, 95],
#         [80, 83, 97],
#         [81, 84, 98],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [79, 82, 96],
#         [79, 82, 96],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [77, 80, 94],
#         [77, 80, 94],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        ...,
#
#        [[20, 29, 19],
#         [21, 30, 20],
#         [21, 30, 20],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [21, 30, 20],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [20, 29, 19],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('/content/drive/MyDrive/DATA_Computer_Vision/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img, (1000, 400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8
h_ratio = 0.2

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (260, 1560, 3)

# %%
new_img = cv2.flip(fix_img,-1)
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/MyDrive/DATA_Computer_Vision/00-puppy.jpg')
cv2_imshow(img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=1950x1300>
# -1
